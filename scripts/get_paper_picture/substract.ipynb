# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np

start_x = 40
start_y = 300
start_z = 85

size = 64
len = 19

time = '2023-10-17_21-17-11'
epoch = '4'

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_fusion.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='red', label='output')

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_xy_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='blue', label='xy')

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_xz_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='green', label='xz')

img = tifffile.imread('rotated_dirty.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='c', label='origin')

plt.legend()
plt.xlabel("Distance(μm)")
plt.ylabel("Normalized intensity")
plt.show()

# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np

start_x = 40
start_y = 300
start_z = 85

size = 64
len = 19

time = '2023-10-17_21-16-23'
epoch = '4'

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_fusion.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='red', label='output')

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_xy_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='blue', label='xy')

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_xz_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='green', label='xz')

img = tifffile.imread('rotated_dirty.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='c', label='origin')

plt.legend()
plt.xlabel("Distance(μm)")
plt.ylabel("Normalized intensity")
plt.show()

# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np

start_x = 40
start_y = 300
start_z = 85

size = 150 # 64
len = 100 # 19

time = '2023-10-17_21-16-23'
epoch = '4'

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_fusion.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='red', label='output')

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_xy_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='blue', label='xy')

img = tifffile.imread('rotated_dirty_'+ epoch +'epoch_'+ time +'_xz_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='green', label='xz')

img = tifffile.imread('rotated_dirty.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='c', label='origin')

plt.legend()
plt.xlabel("Distance(μm)")
plt.ylabel("Normalized intensity")
plt.show()

# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np

start_x = 40
start_y = 300
start_z = 85

size = 150 # 64
len = 100 # 19

time = '2023-10-17_21-16-23'
epoch = '4'

img = tifffile.imread('output_axon_8epoch_fusion.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='red', label='output')

img = tifffile.imread('output_axon_8epoch_xy_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='blue', label='xy')

img = tifffile.imread('output_axon_8epoch_xz_img.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='green', label='xz')

img = tifffile.imread('rotated_dirty.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='c', label='origin')

plt.legend()
plt.xlabel("Distance(μm)")
plt.ylabel("Normalized intensity")
plt.show()

# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np

start_x = 40
start_y = 300
start_z = 85

size = 64
len = 19

img = tifffile.imread('rotated_dirty_8epoch_2023-10-16_20-15-39_fusion.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='red', label='output')

img = tifffile.imread('rotated_dirty.tif')
img = img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size]
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y, color='c', label='origin')

plt.legend()
plt.xlabel("Distance(μm)")
plt.ylabel("Normalized intensity")
plt.show()

# %%
# img = tifffile.imread('rotated_dirty.tif')
# tifffile.imsave('crop_rotated_dirty.tif', img[24:124,313:413,510:610])

# %%
img = tifffile.imread('rotated_dirty.tif')
tifffile.imsave('crop_dirty.tif', img[24:124,263:363,85:185])

img = tifffile.imread('output_axon_8epoch_xz_img.tif')
tifffile.imsave('crop_xy.tif', img[24:124,263:363,85:185])

img = tifffile.imread('output_axon_8epoch_xy_img.tif')
tifffile.imsave('crop_xz.tif', img[24:124,263:363,85:185])

img = tifffile.imread('output_axon_8epoch_fusion.tif')
tifffile.imsave('crop_fusion.tif', img[24:124,263:363,85:185])
# Out:
# C:\Users\WangW\AppData\Local\Temp\ipykernel_40168\1305406070.py:2: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_dirty.tif', img[24:124,263:363,85:185])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_40168\1305406070.py:5: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_xy.tif', img[24:124,263:363,85:185])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_40168\1305406070.py:8: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_xz.tif', img[24:124,263:363,85:185])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_40168\1305406070.py:11: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_fusion.tif', img[24:124,263:363,85:185])

# %%
import random
import tifffile

start_x = random.randint(0,400)
start_y = random.randint(180,540)
start_z = random.randint(180,540)


start_x = 40
start_y = 300
start_z = 85

size = 64

img = tifffile.imread('rotated_dirty.tif')
tifffile.imsave('crop_dirty.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])

img = tifffile.imread('output_axon_8epoch_xz_img.tif')
tifffile.imsave('crop_xy.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])

img = tifffile.imread('output_axon_8epoch_xy_img.tif')
tifffile.imsave('crop_xz.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])

img = tifffile.imread('output_axon_8epoch_fusion.tif')
tifffile.imsave('crop_fusion.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])
# Out:
# C:\Users\WangW\AppData\Local\Temp\ipykernel_26712\853868550.py:16: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_dirty.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_26712\853868550.py:19: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_xy.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_26712\853868550.py:22: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_xz.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_26712\853868550.py:25: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_fusion.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])

# %%
import random
import tifffile

start_x = 40
start_y = 300
start_z = 85

size = 64

img = tifffile.imread('rotated_dirty_10epoch_2023-10-05_23-41-37_fusion.tif')
tifffile.imsave('crop_new_fusion.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])

img = tifffile.imread('rotated_dirty_10epoch_2023-10-05_23-41-37_xy_img.tif')
tifffile.imsave('crop_new_xy.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])

img = tifffile.imread('rotated_dirty_10epoch_2023-10-05_23-41-37_xz_img.tif')
tifffile.imsave('crop_new_xz.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])
# Out:
# C:\Users\WangW\AppData\Local\Temp\ipykernel_30664\2056389690.py:11: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_new_fusion.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_30664\2056389690.py:14: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_new_xy.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])
# C:\Users\WangW\AppData\Local\Temp\ipykernel_30664\2056389690.py:17: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave('crop_new_xz.tif', img[start_x:start_x+size,start_y:start_y+size,start_z:start_z+size])

# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np


len = 19

# list_y = img[8,42,7:7+len]

img = tifffile.imread("crop_fusion.tif")
list_x = list(range(0,len))
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='red', label='output')

img = tifffile.imread("crop_dirty.tif")
list_y = img[19,24,22:22+len]/6000
plt.plot(list_x, list_y, color='c', label='origin')

# img = tifffile.imread("crop_xy.tif")
# list_y = img[19,24,22:22+len]/6000
# plt.plot(list_x, list_y, color='green', label='output_xy')

# img = tifffile.imread("crop_xz.tif")
# list_y = img[19,24,22:22+len]/6000
# plt.plot(list_x, list_y, color='orange', label='output_xz')

plt.legend()
plt.xlabel("Distance(μm)")
plt.ylabel("Normalized intensity")
plt.show()

# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np


len = 19

# list_y = img[8,42,7:7+len]

img = tifffile.imread("crop_fusion.tif")
list_x = list(range(0,len))
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y)
plt.plot(list_x, list_y, color='red', label='output')

img = tifffile.imread("crop_dirty.tif")
list_y = img[19,5,3:3+len]/8192
plt.plot(list_x, list_y)
plt.plot(list_x, list_y, color='c', label='origin')

# img = tifffile.imread("crop_xy.tif")
# list_y = img[19,5,3:3+len]/8192
# plt.plot(list_x, list_y)
# plt.plot(list_x, list_y, color='green', label='output_xy')

# img = tifffile.imread("crop_xz.tif")
# list_y = img[19,5,3:3+len]/8192
# plt.plot(list_x, list_y)
# plt.plot(list_x, list_y, color='orange', label='output_xz')

plt.legend()
plt.xlabel("Distance(μm)")
plt.ylabel("Normalized intensity")
plt.show()

# %%
plt.imshow(img[19,26:26+len,20:25])

# %%
img = tifffile.imread("crop_dirty.tif")

list_x = list(range(0,24))
list_y = img[8,28:52,11]

plt.plot(list_x, list_y)
